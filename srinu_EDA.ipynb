# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("D:/2 Level/Projects in ML/Srinu/data/wildfire_synthetic.xlsx", index_col=0)


df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [34,22,18,70,0.41,1,89,1, 28,45,10,30,0.55,0,40,0, 31,35,20,55,0.47,1,65,1, 26,50,8,20,0.62,0,20,0, 38,18,25,90,0.39,2,110,1]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 34,22,18,70,0.41,1,89,1 to 33,30,19,65,0.46,1,75,1
# Empty DataFrame
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 df.info()
# ----> 2 df.describe()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# ...

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap - EDA")
plt.show()

# %%
df["target_fire"].value_counts().plot(kind="bar")
plt.title("Fire Occurrence Distribution")
plt.show()
